# %%
from dataqa.annotate import annotate

# %%
abstract = """
In a March 2014 interview, Apple designer Jonathan Ive used the iPhone as an example of Apple's ethos of creating high - quality, life - changing products. 
"""

output = {}
annotate(abstract, ["person", "org", "date", "product"], output)
# Out:
# <style scoped>
# .wrapper {
# }
# .flex {
#   display: flex;
# }
# .content {
#   padding: 20px;
#   line-height: 2;
#   font-size: 20px;
#   font-family: "Lato", "Trebuchet MS", Roboto, Helvetica, Arial, sans-serif;
# }
# .label {
#   margin: 5px 10px 5px 0;
#   border: 1px solid white;
#   cursor: pointer;
#   display: block;
#   padding: 1px 10px;
#   position: relative;
#   border-radius: 4px;
# }
# .selected {
#   background: white;
#   color: rgb(31, 41, 55);
# }
# .labelContainer {
#   color: #fff;
#   width: 100%;
#   padding: 12px;
#   font-size: 20px;
#   background: rgb(31, 41, 55);
#   text-align: center;
#   box-sizing: border-box;
#   font-weight: bold;
#   font-family: "Roboto Condensed", "Arial Narrow", sans-serif;
#   text-transform: uppercase;
#   border-top-left-radius: 0;
#   border-top-right-radius: 0;
# }
#
# .span {
#   font-size: 18px;
#   padding: 0.25em 0.4em;
#   background: #ffe184;
#   font-weight: bold;
#   line-height: 1;
#   cursor: pointer;
# }
#
# ...

# %%
output
# Out:
# {'results': []}
